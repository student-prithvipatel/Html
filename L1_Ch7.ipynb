# %%
import mymod

# %%
import mymod as m
print(m.x)
# Out:
# 800

# %%
from mymod import x,sum
print(x)
sum(10,20)
product(20,2)
# Out:
# 800
# sum= 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f774748f08b5> in <module>
#       2 print(x)
#       3 sum(10,20)
# ----> 4 product(20,2)
#
# NameError: name 'product' is not defined

# %%
from mymod import *
print(x)
sum(10,20)
product(20,2)
# Out:
# 800
# sum= 30
# product= 40

# %% [markdown]
# # OS module

# %%
import os
os.getcwd()
# Out:
# 'D:\\Python'

# %%
os.mkdir("D:\\myproject")

# %%
os.rmdir("D:\\myproject")

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '24002171310139_t2.ipynb', '479.txt', '480.txt', '481', '481.txt', 'abc.txt', 'ch-6-10Mark.ipynb', 'city.txt', 'coustomer.txt', 'CST.txt', 'cust.txt', 'D6.txt', 'f1.txt', 'f2.txt', 'f3.txt', 'file1.txt', 'file2.txt', 'file3.txt', 'final.txt', 'friends.txt', 'friends2.txt', 'hello.txt', 'india.txt', 'L1_Ch6.ipynb', 'L1_Ch7.ipynb', 'L2_Ch6.ipynb', 'meet.txt', 'mymod.py', 'mymodule.ipynb', 'output.txt', 'pb477.txt', 'prog.txt', 'programme.txt', 'python1.txt', 'python2.txt', 'solanki.txt', 'story.txt', 'untitled.txt', 'upper.txt', '__pycache__']

# %%
os.chdir("D:\\Prithvi")

# %%
os.getcwd()
# Out:
# 'D:\\Prithvi'

# %%
os.chdir("D:\\Python")

# %%
os.getcwd()
# Out:
# 'D:\\Python'

# %%
import sys
sys.path
# Out:
# ['D:\\Python',
#  'C:\\ProgramData\\Anaconda3\\python38.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\Users\\LJENG\\AppData\\Roaming\\Python\\Python38\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LJENG\\.ipython']

# %%
sys.maxsize
# Out:
# 9223372036854775807

# %%
sys.version
# Out:
# '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]'

# %%
import datetime as dt
print(dt.datetime.now())
print(dt.date.today())
# Out:
# 2025-11-28 12:41:08.568181
# 2025-11-28

# %%
print(dt.time(13,23,45))
a=dt.date(2022,2,23)
print(a.year)
# Out:
# 13:23:45
# 2022

# %% [markdown]
# # create package

# %%
import os
os.mkdir("pkg")

# %%
os.chdir("D:\\Python\pkg")

# %%
# %%writefile mod1.py
def foo():
    print("this is mod1")
# Out:
# Writing mod1.py

# %%
# %%writefile mod2.py
def bar():
    print("this is mod2")
# Out:
# Writing mod2.py

# %%
from pkg import mod1,mod2
mod1.foo()
# Out:
# this is mod1

# %%
mod2.bar()
# Out:
# this is mod2
