# %% [markdown]
# 483.  Write a  python program to read through the mbox-short.txt and figure out who has
# sent the  greatest number of mail messages. The program looks for 'From ' lines and
# takes the    second word of those lines as the person who sent the mail. The program
#  creates a  Python    dictionary that maps the sender's mail address to a count of the
# number of   times they  appear in the file. After the dictionary is produced, the program reads through the dictionary to
# identify the sender with the maximum count (the most prolific sender).
#  Expected Output:
#  {'stephen.marquard@uct.ac.za': 2, 'louis@media.berkeley.edu': 3, 'zqian@umich.edu': 4, 'rjlowe@iupui.edu': 2,
# 'cwen@iupui.edu': 5, 'gsilver@umich.edu': 3, 'wagnermr@iupui.edu': 1, 'antranig@caret.cam.ac.uk': 1,
# 'gopal.ramasammycook@gmail.com': 1, 'david.horwitz@uct.ac.za': 4, 'ray@media.berkeley.edu': 1}
#  cwen@iupui.edu 5

# %%
f=open("mbox-short.txt",encoding="utf-8")
l=[]
d={}
for i in f:
    if not i.startswith("From "):
        continue
    w=i.split()
    l.append(w[1])
for i in l:
    d[i]=d.get(i,0)+1
print(d)
a=max(d.values())
for k,v in d.items():
    if a==v:
        print(k,v)
f.close()
# Out:
# {'stephen.marquard@uct.ac.za': 2, 'louis@media.berkeley.edu': 3, 'zqian@umich.edu': 4, 'rjlowe@iupui.edu': 2, 'cwen@iupui.edu': 5, 'gsilver@umich.edu': 3, 'wagnermr@iupui.edu': 1, 'antranig@caret.cam.ac.uk': 1, 'gopal.ramasammycook@gmail.com': 1, 'david.horwitz@uct.ac.za': 4, 'ray@media.berkeley.edu': 1}
# cwen@iupui.edu 5

# %% [markdown]
# 481. Write a python program to accept string/sentence from user till the user enters “END”. Each string/sentence entered by
# user should be a newline in file. Save all the lines in file and display only those lines which begin with capital letter.
#  Example:
#  Enter Something (for quit enter END):Hi Friends
#  Enter Something (for quit enter END):how are you all
#  Enter Something (for quit enter END):I am fine
#  Enter Something (for quit enter END):hope you all are fine
#  Enter Something (for quit enter END):END
#  The Line started with Capital Letters:
#  Hi Friends
#  I am fine

# %%
f = open("481.txt","w")
while True:
    o = input("Enter Something (for quit enter END): ")
    if o =="END":
        break
    f.write(o+"\n")
f.close()
f1 = open("481.txt")
for i in f1:
    if i[0].isupper():
        print(i)
f1.close()
# Out:
# Enter Something (for quit enter END): hi
# Enter Something (for quit enter END): How are you?
# Enter Something (for quit enter END): END
# How are you?

# %% [markdown]
# 476. Write a Python program to reverse the content of a one file and store it in second file and also convert content of second
# file into uppercase and store it in third file and also count number of Vowels in third file and also print only 2nd line from
# the content of third file.
#  Examples:
#  If data file one contains the following data:
#  Friends are crazy, Friends are naughty !
#  Friends are honest, Friends are  best !
#  Output 1:
#  ! tseb  era sdneirF ,tsenoh era sdneirF
#  ! ythguan era sdneirF ,yzarc era sdneirF
#  Output 2:
#  ! TSEB  ERA SDNEIRF ,TSENOH ERA SDNEIRF
#  ! YTHGUAN ERA SDNEIRF ,YZARC ERA SDNEIRF
#  Output 3:
#  Vowels = 22
#  Output 4:
#  ! YTHGUAN ERA SDNEIRF ,YZARC ERA SDNEIRF

# %%
f = open("file1.txt","r")
s = f.read()
print(s)
f.close()

f2 = open("file2.txt","w+")
data = s[::-1]
f2.write(data)
f2.seek(0)
print(f2.read())
f2.close()

f3 = open("file3.txt","w+")
f3.write(data.upper())
f3.seek(0)
data2=f3.read()
print(data2)
count = 0
for i in data2:
    if i in "AEIOU":
        count+=1
print(count)

f3.seek(0)
data4=f3.readlines()
print("2nd line ",data4[1])
f3.close()
# Out:
# Friends are crazy, Friends are naughty !
#  Friends are honest, Friends are  best !
# ! tseb  era sdneirF ,tsenoh era sdneirF
# ! ythguan era sdneirF ,yzarc era sdneirF
# ! TSEB  ERA SDNEIRF ,TSENOH ERA SDNEIRF
# ! YTHGUAN ERA SDNEIRF ,YZARC ERA SDNEIRF
# 22
# 2nd line  ! YTHGUAN ERA SDNEIRF ,YZARC ERA SDNEIRF

# %%
# 480
f = open("480.txt")
f2 = open("output.txt","w")
while True:
    x = f.readline()
    if len(x)!= 0:
        if x[0]=="#":
            continue
        else :
            if "#" in x :
                for i in range(1,len(x)):
                    if x[i]=="#":
                        f2.write(x[:i]+"\n")
            else :
                f2.write(x)
    else:
        break
f.close()
f2.close()
